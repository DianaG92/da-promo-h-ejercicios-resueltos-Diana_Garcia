# %% [markdown]
# EJERCICIOS DE ESTADISTICA DESCRIPTIVA

# %% [markdown]
# Utilizando el DataFrame que usamos para los ejercicios de la clase invertida de ayer, contestad a las siguientes preguntas:

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in /home/admin_diana/anaconda3/lib/python3.9/site-packages (1.7.1)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /home/admin_diana/anaconda3/lib/python3.9/site-packages (from scipy) (1.20.3)

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# Evaluar linealidad de las relaciones entre las variables
from scipy.stats import shapiro, kstest

pd.set_option('display.max_columns', None)

# Gestión de los warnings
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("rating_insights2.csv", index_col=0)
df.head()
# Out:
#                                                title  price  retail_price  \
# 1  SSHOUSE Summer Casual Sleeveless Soirée Party ...   8.00            22
# 2  Nouvelle mode d'été femmes robe décontractée c...   4.90             8
# 3   Summer Women s Fashion Lace Up Tie Pants Plus...   4.93             6
# 4  Nouvelle mode d'été femmes robe décontractée c...   5.65            10
# 5  Nouvelle mode d'été femmes robe décontractée c...   5.65            10
#
#    units_sold uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 1       20000             Si         3.45          6135             2269.0
# 2        1000             Si         3.83            99               43.0
# 3         100             No         3.77            47               22.0
# 4         100             Si         2.86             7                1.0
# 5         100             Si         2.86             7                1.0
#
#    rating_four_count  rating_three_count  rating_two_count  rating_one_count  \
# 1             1027.0              1118.0             644.0            1077.0
# 2               18.0                23.0               8.0               7.0
# 3                7.0                 8.0               5.0               5.0
# 4                1.0                 2.0               2.0               1.0
# 5                1.0                 2.0               2.0               1.0
#
#   badge_local_product badge_product_quality badge_fast_shipping  \
# 1                  No                 Buena                  No
# 2                  No                 Buena                  No
# 3                  No                 Buena                  No
# 4                  No                 Buena                  No
# 5                  No                 Buena                  No
#
#                                                 tags product_color  \
# 1  Mini,womens dresses,Summer,Patchwork,fashion d...         green
# 2  Summer,Fashion,Necks,Beach,Dress,Loose,beach d...         white
# 3  Summer,Shorts,Lace,pants,Waist,Short pants,Yel...           red
# 4  Summer,Fashion,Necks,Skirts,Dress,Loose,Women'...         black
# 5  Summer,Fashion,Necks,Skirts,Dress,Loose,Women'...         black
#
#   product_variation_size_id shipping_option_name  shipping_option_price  \
# 1                        XS   Livraison standard                      2
# 2                       XXS   Livraison standard                      1
# 3                         S    Standard Shipping                      1
# 4                       XXS   Livraison standard                      1
# 5                       XXS   Livraison standard                      1
#
#   shipping_is_express  countries_shipped_to  inventory_total origin_country  \
# 1                  No                    41               50             CN
# 2                  No                    41               50             CN
# 3                  No                    41               50             CN
# 4                  No                    41               50             CN
# 5                  No                    41               50             CN
#
#   merchant_name  merchant_info_subtitle  merchant_rating_count  \
# 1     sarahouse     83 % avis positifs                   17752
# 2     sarahouse     83 % avis positifs                   17752
# 3     sarahouse  83% Positive Feedback                   17752
# 4     sarahouse     83 % avis positifs                   17752
# 5     sarahouse     83 % avis positifs                   17752
#
#                 merchant_id                                      product_url  \
# 1  56458aa03a698c35c9050988  https://www.wish.com/c/58940d436a0d3d5da4e95a38
# 2  56458aa03a698c35c9050988  https://www.wish.com/c/5df2576d68963c1660471f9a
# 3  56458aa03a698c35c9050988  https://www.wish.com/c/5d58daef3159a812b05933d2
# 4  56458aa03a698c35c9050988  https://www.wish.com/c/5e9fa7de39682a0043ab7898
# 5  56458aa03a698c35c9050988  https://www.wish.com/c/5e9fa7de39682a0043ab7898
#
#                  product_id  listed_products  total_units_sold  \
# 1  58940d436a0d3d5da4e95a38                6             21400
# 2  5df2576d68963c1660471f9a                6             21400
# 3  5d58daef3159a812b05933d2                6             21400
# 4  5e9fa7de39682a0043ab7898                6             21400
# 5  5e9fa7de39682a0043ab7898                6             21400
#
#    mean_units_sold_per_product  rating_employee  merchant_ratings_count  \
# 1                       3567.0              3.9                 17752.0
# 2                       3567.0              3.9                 17752.0
# 3                       3567.0              3.9                 17752.0
# 4                       3567.0              3.9                 17752.0
# 5                       3567.0              3.9                 17752.0
#
#    mean_product_prices  mean_retail_prices  mean_product_ratings_count  \
# 1                 5.68               10.33                      1057.0
# 2                 5.68               10.33                      1057.0
# 3                 5.68               10.33                      1057.0
# 4                 5.68               10.33                      1057.0
# 5                 5.68               10.33                      1057.0
#
#    discount_percentage seller_reputation
# 1               1400.0           Regular
# 2                310.0           Regular
# 3                107.0           Regular
# 4                435.0           Regular
# 5                435.0           Regular

# %% [markdown]
# 1. La variable `price` representa el precio de los productos. Calcula tanto la media como la mediana de los precios y explica la diferencia entre ambas medidas. Proporciona ejemplos de situaciones en las que la mediana podría ser preferible sobre la media.

# %%
print(f"La media del precio de los productos es: {round(df['price'].mean(), 2)}")

print(f"La mediana del precio de los productos es: {df['price'].median()}")
# Out:
# La media del precio de los productos es: 8.32
# La mediana del precio de los productos es: 8.0

# %% [markdown]
# 2. Crea una tabla de correlación que muestre cómo se relacionan las variables `price`, `retail_price`, `units_sold`, `rating_sold`, y `rating_count`. Interpreta los resultados y discute si hay alguna correlación significativa entre estas variables.

# %%
df[["price", "retail_price", "units_sold", "rating_count"]].corr(method = "spearman").reset_index()
# Out:
#           index     price  retail_price  units_sold  rating_count
# 0         price  1.000000      0.547329    0.053751      0.123012
# 1  retail_price  0.547329      1.000000   -0.017243      0.028703
# 2    units_sold  0.053751     -0.017243    1.000000      0.938417
# 3  rating_count  0.123012      0.028703    0.938417      1.000000

# %% [markdown]
# 3. Utiliza una tabla de contingencia para analizar la relación entre las variables categóricas `uses_ad_boosts` y `badge_product_quality`. ¿Cómo afecta la calidad del producto al uso de anuncios promocionales? Proporciona interpretaciones basadas en la tabla de contingencia.

# %%
pd.crosstab(df["uses_ad_boosts"], df["badge_product_quality"], normalize=True)
# Out:
# badge_product_quality     Buena  Excelente
# uses_ad_boosts
# No                     0.520675   0.044726
# Si                     0.401688   0.032911

# %% [markdown]
# 4. Crea una tabla de contingencia que examine la relación entre las variables categóricas `badge_local_product` y `badge_fast_shipping`. ¿Hay alguna tendencia en la que los productos locales estén más asociados con envíos rápidos? Explícalo.

# %%
pd.crosstab(df["badge_local_product"], df["badge_fast_shipping"], normalize=True)
# Out:
# badge_fast_shipping        No        Si
# badge_local_product
# No                   0.979747  0.005907
# Si                   0.010127  0.004219

# %% [markdown]
# 5. Calcula la media y la mediana de la variable `mean_product_prices`. ¿Cómo se comparan estas medidas? ¿Qué puedes inferir sobre la distribución de los precios promedio de los productos?

# %%
df["mean_product_prices"].agg(["mean", "median"]).reset_index()
# Out:
#     index  mean_product_prices
# 0    mean             8.304996
# 1  median             8.000000

# %% [markdown]
# 6. Realiza un análisis de correlación entre `total_units_sold` y `mean_product_ratings_count`. ¿Existe una relación entre la cantidad total de unidades vendidas y la calificación promedio de los productos? Explica los resultados.

# %%
df[["total_units_sold", "mean_product_ratings_count"]].corr(method = "spearman")
# Out:
#                             total_units_sold  mean_product_ratings_count
# total_units_sold                    1.000000                    0.877427
# mean_product_ratings_count          0.877427                    1.000000

# %% [markdown]
# 7. Crea una tabla de contingencia que examine la relación entre las variables categóricas `badge_local_product` y `seller_reputation`. ¿Cómo se relacionan las calificaciones de los empleados con la reputación del vendedor? Proporciona interpretaciones basadas en la tabla de contingencia.

# %%
pd.crosstab(df["badge_local_product"], df["seller_reputation"])
# Out:
# seller_reputation    Buena  Regular
# badge_local_product
# No                     679      489
# Si                      16        1

# %% [markdown]
# 8. Calcula la media y la mediana de la variable `discount_percentage`. ¿Qué puedes decir sobre los descuentos promedio en los productos? ¿Hay valores atípicos en esta variable?

# %%
df["discount_percentage"].agg(["mean", "median"]).reset_index()
# Out:
#     index  discount_percentage
# 0    mean           1475.54346
# 1  median             19.00000

# %% [markdown]
# 9. Utiliza una tabla de contingencia para analizar cómo se relacionan las variables categóricas `badge_fast_shipping` y `seller_reputation`. ¿Qué puedes concluir sobre la distribución de las calificaciones altas?

# %%
pd.crosstab(df["badge_fast_shipping"], df["seller_reputation"], normalize=True)
# Out:
# seller_reputation       Buena   Regular
# badge_fast_shipping
# No                   0.577215  0.412658
# Si                   0.009283  0.000844
