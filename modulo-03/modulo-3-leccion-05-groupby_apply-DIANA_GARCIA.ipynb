# %% [markdown]
# EJERCICIOS DE GROUP BY Y APPLY

# %% [markdown]
# En estos usaremos el conjunto de datos que guardamos ayer en los ejercicios de la clase invertida. Los ejercicios que os planteamos hoy son:

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

# %%
df_unido = pd.read_csv("rating_insights.csv", index_col=0)

df_unido.head(2)
# Out:
#                                                title  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...   16.0            14
# 1  SSHOUSE Summer Casual Sleeveless Soirée Party ...    8.0            22
#
#    units_sold  uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 0         100               0         3.76            54               26.0
# 1       20000               1         3.45          6135             2269.0
#
#    rating_four_count  rating_three_count  rating_two_count  rating_one_count  \
# 0                8.0                10.0               1.0               9.0
# 1             1027.0              1118.0             644.0            1077.0
#
#    badge_local_product  badge_product_quality  badge_fast_shipping  \
# 0                    0                      0                    0
# 1                    0                      0                    0
#
#                                                 tags product_color  \
# 0  Summer,Fashion,womenunderwearsuit,printedpajam...         white
# 1  Mini,womens dresses,Summer,Patchwork,fashion d...         green
#
#   product_variation_size_id shipping_option_name  shipping_option_price  \
# 0                         M   Livraison standard                      4
# 1                        XS   Livraison standard                      2
#
#    shipping_is_express  countries_shipped_to  inventory_total origin_country  \
# 0                    0                    34               50             CN
# 1                    0                    41               50             CN
#
#   merchant_name merchant_info_subtitle  merchant_rating_count  \
# 0      zgrdejia                    NaN                    568
# 1     sarahouse    83 % avis positifs                   17752
#
#    merchant_rating               merchant_id  \
# 0         4.128521  595097d6a26f6e070cb878d1
# 1         3.899673  56458aa03a698c35c9050988
#
#                                        product_url                product_id  \
# 0  https://www.wish.com/c/5e9ae51d43d6a96e303acdb0  5e9ae51d43d6a96e303acdb0
# 1  https://www.wish.com/c/58940d436a0d3d5da4e95a38  58940d436a0d3d5da4e95a38
#
#    listed_products  total_units_sold  mean_units_sold_per_product  \
# 0                1               100                        100.0
# 1                6             21400                       3567.0
#
#    rating_employee  merchant_ratings_count  mean_product_prices  \
# 0            4.129                   568.0                16.00
# 1            3.900                 17752.0                 5.68
#
#    mean_retail_prices  average_discount  mean_discount  \
# 0               14.00             -14.0         -14.00
# 1               10.33              38.0          37.83
#
#    mean_product_ratings_count
# 0                        54.0
# 1                      1057.0

# %% [markdown]
# 1. Total de unidades vendidas por país de origen del vendedor. Debéis agrupar los datos según el país de origen del vendedor y calcular el total de unidades vendidas para cada país. Esto nos dará una idea de qué países tienen una mayor participación en las ventas totales y cuáles tienen menos. Devuelve los resultados en un DataFrame ordenados de mayor a menor en función de la cantidad de unidades vendidas.

# %%
# Usamos el método ".reset_index()" para convertir la Serie resultante de nuevo en un DataFrame, reestableciendo el índice.
df_unido.groupby("origin_country")["units_sold"].sum().reset_index()
# Out:
#   origin_country  units_sold
# 0             AT         100
# 1             CN     6651245
# 2             GB        1000
# 3             SG       20100
# 4             US       43560
# 5             VE         350

# %%
df_ordenado = df_unido.sort_values("units_sold", ascending=False)

df_ordenado.head()
# Out:
#                                                   title  price  retail_price  \
# 519   T-shirt à manches courtes en mousseline de soi...   5.00            33
# 1295  Femmes dentelle manches courtes hauts hauts ch...   7.00            22
# 50    2018 New Fashion Women's Tops Sexy Strappy Sle...   5.00            25
# 1386  Nouvelle arrivée femmes été sexy robe de soiré...   5.67            19
# 468   Nouveau Aeeival Femmes Vêtements À Manches Lon...   8.00             7
#
#       units_sold  uses_ad_boosts  rating_sold  rating_count  \
# 519       100000               0         3.98         13789
# 1295      100000               1         3.82         11913
# 50        100000               1         3.83         17980
# 1386      100000               0         3.53         18393
# 468       100000               1         3.76         11062
#
#       rating_five_count  rating_four_count  rating_three_count  \
# 519              6862.0             2836.0              2131.0
# 1295             5355.0             2430.0              1974.0
# 50               8290.0             3483.0              2951.0
# 1386             6769.0             3404.0              3658.0
# 468              4663.0             2418.0              1868.0
#
#       rating_two_count  rating_one_count  badge_local_product  \
# 519              901.0            1059.0                    0
# 1295             960.0            1194.0                    0
# 50              1410.0            1846.0                    0
# 1386            2003.0            2559.0                    0
# 468              842.0            1271.0                    0
#
#       badge_product_quality  badge_fast_shipping  \
# 519                       0                    0
# 1295                      0                    0
# 50                        0                    0
# 1386                      0                    0
# 468                       0                    0
#
#                                                    tags product_color  \
# 519   Summer,Plus Size,Cotton T Shirt,chiffon,Long S...        orange
# 1295  blouse,Fashion,Shirt,boho,Tops,summer t-shirts...           NaN
# 50    blouse,Plus Size,Lace,lace top,Tops,Fashion,st...         white
# 1386  slim dress,Mini,Elegant,Dress,Mini dress,turtl...          grey
# 468   roupas femininas,womens dresses,Lace,gowns,Lon...   light green
#
#      product_variation_size_id shipping_option_name  shipping_option_price  \
# 519                          S   Livraison standard                      1
# 1295                         S   Livraison standard                      2
# 50                           S   Livraison standard                      1
# 1386                         M   Livraison standard                      1
# 468                          M   Livraison standard                      2
#
#       shipping_is_express  countries_shipped_to  inventory_total  \
# 519                     0                    41               50
# 1295                    0                    46               50
# 50                      0                    41               50
# 1386                    0                    37               50
# 468                     0                    38               50
#
#      origin_country                      merchant_name merchant_info_subtitle  \
# 519              CN                         bigcompany    86 % avis positifs
# 1295             CN                 primesalecolimited    90 % avis positifs
# 50               CN                            leiston    84 % avis positifs
# 1386             CN                   fashionstore0408    84 % avis positifs
# 468              CN  shenzhenlongdragontechnologycoltd    87 % avis positifs
#
#       merchant_rating_count  merchant_rating               merchant_id  \
# 519                  366898         4.036081  53082ea15aefb07dfe1f2a4f
# 1295                 320031         4.218866  5357bcf2bb72c5504882e889
# 50                   139223         3.933581  5708773c3c02161b3f8c7900
# 1386                  19248         3.889131  570f3a713a698c14278bb51e
# 468                  108048         4.052504  5417aada4ad3ab27e954b76c
#
#                                           product_url  \
# 519   https://www.wish.com/c/53897eeeafddf70c91af1cda
# 1295  https://www.wish.com/c/567cb0925ff12c4829f07dfb
# 50    https://www.wish.com/c/5b07a7c6e997b33c6f9947da
# 1386  https://www.wish.com/c/571adeab62cce546f1a46bc0
# 468   https://www.wish.com/c/54bdf18039b8c045f118936a
#
#                     product_id  listed_products  total_units_sold  \
# 519   53897eeeafddf70c91af1cda                1            100000
# 1295  567cb0925ff12c4829f07dfb                2            120000
# 50    5b07a7c6e997b33c6f9947da                5            107100
# 1386  571adeab62cce546f1a46bc0                1            100000
# 468   54bdf18039b8c045f118936a                2            100007
#
#       mean_units_sold_per_product  rating_employee  merchant_ratings_count  \
# 519                      100000.0            4.036                366898.0
# 1295                      60000.0            4.219                320031.0
# 50                        21420.0            3.934                139223.0
# 1386                     100000.0            3.889                 19248.0
# 468                       50004.0            4.053                108048.0
#
#       mean_product_prices  mean_retail_prices  average_discount  \
# 519                  5.00                33.0              85.0
# 1295                 9.00                20.0              54.0
# 50                   7.76                34.2              61.0
# 1386                 5.67                19.0              71.0
# 468                  8.00                 8.0              -1.0
#
#       mean_discount  mean_product_ratings_count
# 519            85.0                     13789.0
# 1295           54.0                      8836.0
# 50             61.0                      4010.0
# 1386           71.0                     18393.0
# 468            -1.0                      5531.0

# %% [markdown]
# 2. Estadísticas de precio por país de envío. Vamos a explorar el precio promedio y el precio máximo de los productos según el país al que se envían. Al hacer esto, podremos entender cómo varían los precios según el destino del envío y si hay alguna tendencia interesante que valga la pena analizar.  Devuelve los resultados en un DataFrame.

# %%
# Usamos el método ".agg()" para aplicar múltiples funciones de agregación a las columnas de un DataFrame.
df_unido.groupby("countries_shipped_to")["price"].agg(["mean", "max"]).reset_index()
# Out:
#     countries_shipped_to       mean   max
# 0                      6   6.000000   6.0
# 1                      8   5.298333   6.0
# 2                      9   6.707500   8.0
# 3                     10  12.111429  18.0
# 4                     11   8.500000  12.0
# ..                   ...        ...   ...
# 89                   135   5.355000   7.0
# 90                   137   8.243333  11.0
# 91                   138   6.036667   9.0
# 92                   139   8.975000  13.0
# 93                   140   5.220000   7.0
#
# [94 rows x 3 columns]

# %% [markdown]
# 3. Conteo de productos con y sin distintivo de producto local. Vamos a clasificar los productos según si tienen o no un distintivo de producto local. Luego, calcularemos el conteo de productos en cada categoría para comprender cuántos productos tienen este distintivo y cuántos no. Esto puede proporcionarnos información sobre cómo se promocionan los productos con esta característica. Devuelve los resultados en un DataFrame.

# %% [markdown]
# ### EJERCICIO SIN TERMINAR ‼‼‼‼‼📢🔊

# %%
df_unido["badge_local_product"].value_counts().reset_index()
# Out:
#    index  badge_local_product
# 0      0                 1544
# 1      1                   29

# %%
#df_conteo = df_unido["badge_local_product"].value_counts().reset_index()
#df_conteo.columns = ["badge_local_product", "product_count"]

# Convertir los valores booleanos a cadenas para mayor claridad en la presentación
#df_conteo["badge_local_product"] = df_conteo["badge_local_product"].map({True: 'Local', False: 'Non-local'})

#df_conteo

# %% [markdown]
# 4. Promedio de unidades vendidas por tipo de envío. Nuestro objetivo es analizar cómo se correlaciona el tipo de envío (columna `shipping_option_name`) con las unidades vendidas. Vamos a calcular el promedio de unidades vendidas para cada tipo de opción de envío. Esto podría ayudarnos a determinar si ciertos métodos de envío están relacionados con un mayor o menor rendimiento en las ventas. Devuelve los resultados en un DataFrame.  ¿Qué conclusiones puedes sacar de este resultado?

# %%
df_unido.groupby("shipping_option_name")["units_sold"].mean().reset_index()
# Out:
#        shipping_option_name    units_sold
# 0        Ekspresowa wysyłka  10000.000000
# 1              Envio Padrão   2488.888889
# 2              Envío normal   3220.000000
# 3        Expediere Standard    400.000000
# 4         Livraison Express    400.000000
# 5        Livraison standard   4383.756631
# 6       Spedizione standard    550.000000
# 7         Standard Shipping   4216.666667
# 8       Standardowa wysyłka  10033.333333
# 9           Standardversand    100.000000
# 10         Standart Gönderi   5500.000000
# 11     Стандартная доставка   3366.666667
# 12            الشحن القياسي    325.000000
# 13      การส่งสินค้ามาตรฐาน   5000.000000
# 14  ការដឹកជញ្ជូនតាមស្តង់ដារ  10000.000000

# %% [markdown]
# 5. Reemplazo de valores. A lo largo del DataFrame tenemos algunas columnas cuyos valores son cero y uno, lo que podría llevar a confusión en su interpretación. Estas columnas son:
#
#     - `uses_ad_boosts`: La cual indica si la plataforma de comercio electrónico ha utilizado o no la función de impulso de anuncios.  Si el valor de uses_ad_boosts es 1, indica que el vendedor ha invertido en publicidad adicional para resaltar el producto. Si el valor es 0, no ha sido promocionado a través de anuncios adicionales.
#
#     - `badge_local_product`: Indica que el producto se produce, fabrica o se envía desde la misma región o país en el que se realiza la transacción de compra. Si el valor es 1, significa que el producto tiene un distintivo que lo califica como un producto local. Si el valor es 0, indica que el producto no tiene este distintivo.
#
#     - `badge_product_quality`: Indica que el producto cumple con ciertos estándares de calidad, características o evaluaciones positivas por parte de los consumidores. Si el valor es 1, significa que el producto tiene un distintivo que lo califica como un producto de alta calidad. Si el valor es 0, indica que el producto no tiene este distintivo de calidad.
#
#     - `badge_fast_shipping`: Indica que el producto se enviará y entregará en un plazo más corto en comparación con otras opciones de envío estándar. Si el valor es 1, significa que el producto tiene un distintivo que indica un envío rápido. Si el valor es 0, indica que el producto no tiene este distintivo de envío rápido.
#
#     - `shipping_is_express`: Se refiere a si una opción de envío para un producto en una plataforma de comercio electrónico se considera como "envío exprés" o "envío rápido". Si el valor es 1, significa que la opción de envío asociada se considera como una entrega rápida o exprés. Si el valor es 0, indica que la opción de envío no se considera como envío exprés.
#
#     Todas estas columnas cumplen un patrón, y es que los 0 corresponden con 'No' y los 1 con 'Si'. Por esto, en este ejercicio deberéis reemplazar los 0: No y los 1: Si.

# %%
# Primero creamos un diccionario donde queremos reemplazar los 0 por "No" y los 1 por "Sí".
diccionario_mapa1 = {0: "No", 1: "Si"}

# %%
columnas_mapa = ["uses_ad_boosts", "badge_local_product", "badge_product_quality", "badge_fast_shipping","shipping_is_express"]

# Usamos ".applymap(.get)" para aplicar un mapeo a múltiples columnas en un DataFrame.
df_unido[columnas_mapa] = df_unido[columnas_mapa].applymap(diccionario_mapa1.get)

df_unido.sample(2)
# Out:
#                                                   title  price  retail_price  \
# 1045  2020 Femmes Mode Col En V Couleur Unie Slim Fi...   4.81            30
# 958   S-5XL Femmes De Mode D'été Automne Casual Barb...  11.00            10
#
#       units_sold uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 1045           3             No         5.00             0                NaN
# 958          100             Si         3.13            45               11.0
#
#       rating_four_count  rating_three_count  rating_two_count  \
# 1045                NaN                 NaN               NaN
# 958                11.0                 7.0               5.0
#
#       rating_one_count badge_local_product badge_product_quality  \
# 1045               NaN                  No                    No
# 958               11.0                  No                    No
#
#      badge_fast_shipping                                               tags  \
# 1045                  No  Summer,Shorts,Slim Fit,slim,twopiecesoutfit,V-...
# 958                   No  Summer,Women Rompers,trousers,Tank,Fashion,Lon...
#
#      product_color product_variation_size_id shipping_option_name  \
# 1045         green                        XS   Livraison standard
# 958           blue                        XS   Livraison standard
#
#       shipping_option_price shipping_is_express  countries_shipped_to  \
# 1045                      1                  No                    43
# 958                       3                  No                    26
#
#       inventory_total origin_country merchant_name merchant_info_subtitle  \
# 1045               50             CN    choicstore    85 % avis positifs
# 958                50             CN   hanziye1234    71 % avis positifs
#
#       merchant_rating_count  merchant_rating               merchant_id  \
# 1045                  11378         3.990508  564d8f2f3a698c01d97fbb81
# 958                     364         3.381868  5dd790db4cc6678b7441ba5d
#
#                                           product_url  \
# 1045  https://www.wish.com/c/5eb618659ac3e01e76161a4a
# 958   https://www.wish.com/c/5eaa6e36fa62c322bb57f78d
#
#                     product_id  listed_products  total_units_sold  \
# 1045  5eb618659ac3e01e76161a4a                1                 3
# 958   5eaa6e36fa62c322bb57f78d                2               200
#
#       mean_units_sold_per_product  rating_employee  merchant_ratings_count  \
# 1045                          3.0            3.991                 11378.0
# 958                         100.0            3.382                   364.0
#
#       mean_product_prices  mean_retail_prices  average_discount  \
# 1045                 4.81                30.0              84.0
# 958                 11.00                10.0             -10.0
#
#       mean_discount  mean_product_ratings_count
# 1045           84.0                         0.0
# 958           -10.0                        45.0

# %% [markdown]
# 6. Calificación de la calidad del producto. Sobreescribe la columna `badge_product_quality`  utilizando `apply()` para asignar "Buena" a las filas donde 'badge_product_quality' sea "No" y "Excelente" donde sea "Si".

# %%
def calificacion_calidad(valor):
    if valor == "No":
        return "Buena"
    elif valor == "Si":
        return "Excelente"
    else:
        return valor

df_unido['badge_product_quality'] = df_unido['badge_product_quality'].apply(lambda x: calificacion_calidad(x))

df_unido.sample(2)
# Out:
#                                                   title  price  retail_price  \
# 890   Mode féminine Décontracté à manches courtes Te...    9.0             8
# 1073  Fashion Femmes Combinaisons Salopette Bohemia ...   13.0            15
#
#       units_sold uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 890          100             No         4.10            10                5.0
# 1073         100             No         3.49            55               21.0
#
#       rating_four_count  rating_three_count  rating_two_count  \
# 890                 3.0                 1.0               0.0
# 1073               11.0                 6.0               8.0
#
#       rating_one_count badge_local_product badge_product_quality  \
# 890                1.0                  No                 Buena
# 1073               9.0                  No                 Buena
#
#      badge_fast_shipping                                               tags  \
# 890                   No  blouse,tunics women,Fashion,tunic,Necks,t shir...
# 1073                  Si  bohemia,sleeveless,Shorts,Rose,long dress,Vint...
#
#      product_color product_variation_size_id shipping_option_name  \
# 890         purple                        XS   Livraison standard
# 1073         green              S(bust 88cm)   Livraison standard
#
#       shipping_option_price shipping_is_express  countries_shipped_to  \
# 890                       3                  No                    26
# 1073                      3                  No                    33
#
#       inventory_total origin_country merchant_name merchant_info_subtitle  \
# 890                50             CN        yxz888    85 % avis positifs
# 1073               50             CN    huanjun411    93 % avis positifs
#
#       merchant_rating_count  merchant_rating               merchant_id  \
# 890                    4402         4.022944  5aed66b2f0b75f35a1bd6615
# 1073                   3276         4.428571  582ff4f70299bc4f4b90d203
#
#                                           product_url  \
# 890   https://www.wish.com/c/5eb3a12911440f2634f0dbb3
# 1073  https://www.wish.com/c/5cbe81430aa3a4566e6ee369
#
#                     product_id  listed_products  total_units_sold  \
# 890   5eb3a12911440f2634f0dbb3                1               100
# 1073  5cbe81430aa3a4566e6ee369                2               200
#
#       mean_units_sold_per_product  rating_employee  merchant_ratings_count  \
# 890                         100.0            4.023                  4402.0
# 1073                        100.0            4.429                  3276.0
#
#       mean_product_prices  mean_retail_prices  average_discount  \
# 890                   9.0                 8.0             -12.0
# 1073                 13.0                15.0              14.0
#
#       mean_discount  mean_product_ratings_count
# 890           -12.0                        10.0
# 1073           14.0                        55.0

# %% [markdown]
# 7. Cálculo de descuento. Crea una nueva columna `discount_percentage` utilizando `apply()` que calcule el porcentaje de descuento basado en las columnas 'price' y 'retail_price', redondea los decimales a 2. Después elimina las columnas de `average_discount` y `mean_discount`

# %%
def calcular_descuento(fila):
    price = fila["price"]
    retail_price = fila["retail_price"]
    if retail_price != 0:
        discount_percentage = ((retail_price - price)) * 100
        return round(discount_percentage, 2)
    else:
        return 0
    
df_unido["discount_percentage"] = df_unido.apply(calcular_descuento, axis=1)

df_unido = df_unido.drop(["average_discount", "mean_discount"], axis=1)

df_unido.tail(2)
# Out:
#                                                   title  price  retail_price  \
# 1571  Nouveautés Hommes Siwmwear Beach-Shorts Hommes...    5.0            19
# 1572  Pantalon de yoga pour femmes à la mode Slim Fi...    7.0             6
#
#       units_sold uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 1571         100             No         3.71            59               24.0
# 1572         100             Si         4.07            14                8.0
#
#       rating_four_count  rating_three_count  rating_two_count  \
# 1571               15.0                 8.0               3.0
# 1572                3.0                 1.0               0.0
#
#       rating_one_count badge_local_product badge_product_quality  \
# 1571               9.0                  No                 Buena
# 1572               2.0                  No                 Buena
#
#      badge_fast_shipping                                               tags  \
# 1571                  No  runningshort,Beach Shorts,beachpant,menbeachsh...
# 1572                  No  Summer,Leggings,slim,Yoga,pants,Slim Fit,Women...
#
#      product_color product_variation_size_id shipping_option_name  \
# 1571         white                    SIZE S   Livraison standard
# 1572           red                         S   Livraison standard
#
#       shipping_option_price shipping_is_express  countries_shipped_to  \
# 1571                      2                  No                    11
# 1572                      2                  No                    41
#
#       inventory_total origin_country   merchant_name merchant_info_subtitle  \
# 1571               50             CN      shixueying    86 % avis positifs
# 1572               50             CN  aishoppingmall    90 % avis positifs
#
#       merchant_rating_count  merchant_rating               merchant_id  \
# 1571                    210         3.961905  5b42da1bf64320209fc8da69
# 1572                   7023         4.235939  5a409cf87b584e7951b2e25f
#
#                                           product_url  \
# 1571  https://www.wish.com/c/5e74be96034d613d42b52dfe
# 1572  https://www.wish.com/c/5e857321f53c3d2d8f25e7ed
#
#                     product_id  listed_products  total_units_sold  \
# 1571  5e74be96034d613d42b52dfe                1               100
# 1572  5e857321f53c3d2d8f25e7ed                1               100
#
#       mean_units_sold_per_product  rating_employee  merchant_ratings_count  \
# 1571                        100.0            3.962                   210.0
# 1572                        100.0            4.236                  7023.0
#
#       mean_product_prices  mean_retail_prices  mean_product_ratings_count  \
# 1571                  5.0                19.0                        59.0
# 1572                  7.0                 6.0                        14.0
#
#       discount_percentage
# 1571               1400.0
# 1572               -100.0

# %% [markdown]
# 8. Evaluación de la valoración del vendedor. Utiliza `apply()` para crear una nueva columna 'seller_reputation' donde los valores sean "Buena" si 'merchant_rating' es mayor o igual a 4, y "Regular" si es menor a 4. Después elimina la columna `merchant_rating`.

# %%
def valoracion_vendedor(valor):
    if valor is not None and valor >= 4:
        return "Buena"
    else:
        return "Regular"

df_unido["seller_reputation"] = df_unido["merchant_rating"].apply(lambda x: valoracion_vendedor(x))

df_unido = df_unido.drop("merchant_rating", axis=1)

df_unido.head()
# Out:
#                                                title  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1  SSHOUSE Summer Casual Sleeveless Soirée Party ...   8.00            22
# 2  Nouvelle mode d'été femmes robe décontractée c...   4.90             8
# 3   Summer Women s Fashion Lace Up Tie Pants Plus...   4.93             6
# 4  Nouvelle mode d'été femmes robe décontractée c...   5.65            10
#
#    units_sold uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 0         100             No         3.76            54               26.0
# 1       20000             Si         3.45          6135             2269.0
# 2        1000             Si         3.83            99               43.0
# 3         100             No         3.77            47               22.0
# 4         100             Si         2.86             7                1.0
#
#    rating_four_count  rating_three_count  rating_two_count  rating_one_count  \
# 0                8.0                10.0               1.0               9.0
# 1             1027.0              1118.0             644.0            1077.0
# 2               18.0                23.0               8.0               7.0
# 3                7.0                 8.0               5.0               5.0
# 4                1.0                 2.0               2.0               1.0
#
#   badge_local_product badge_product_quality badge_fast_shipping  \
# 0                  No                 Buena                  No
# 1                  No                 Buena                  No
# 2                  No                 Buena                  No
# 3                  No                 Buena                  No
# 4                  No                 Buena                  No
#
#                                                 tags product_color  \
# 0  Summer,Fashion,womenunderwearsuit,printedpajam...         white
# 1  Mini,womens dresses,Summer,Patchwork,fashion d...         green
# 2  Summer,Fashion,Necks,Beach,Dress,Loose,beach d...         white
# 3  Summer,Shorts,Lace,pants,Waist,Short pants,Yel...           red
# 4  Summer,Fashion,Necks,Skirts,Dress,Loose,Women'...         black
#
#   product_variation_size_id shipping_option_name  shipping_option_price  \
# 0                         M   Livraison standard                      4
# 1                        XS   Livraison standard                      2
# 2                       XXS   Livraison standard                      1
# 3                         S    Standard Shipping                      1
# 4                       XXS   Livraison standard                      1
#
#   shipping_is_express  countries_shipped_to  inventory_total origin_country  \
# 0                  No                    34               50             CN
# 1                  No                    41               50             CN
# 2                  No                    41               50             CN
# 3                  No                    41               50             CN
# 4                  No                    41               50             CN
#
#   merchant_name  merchant_info_subtitle  merchant_rating_count  \
# 0      zgrdejia                     NaN                    568
# 1     sarahouse     83 % avis positifs                   17752
# 2     sarahouse     83 % avis positifs                   17752
# 3     sarahouse  83% Positive Feedback                   17752
# 4     sarahouse     83 % avis positifs                   17752
#
#                 merchant_id                                      product_url  \
# 0  595097d6a26f6e070cb878d1  https://www.wish.com/c/5e9ae51d43d6a96e303acdb0
# 1  56458aa03a698c35c9050988  https://www.wish.com/c/58940d436a0d3d5da4e95a38
# 2  56458aa03a698c35c9050988  https://www.wish.com/c/5df2576d68963c1660471f9a
# 3  56458aa03a698c35c9050988  https://www.wish.com/c/5d58daef3159a812b05933d2
# 4  56458aa03a698c35c9050988  https://www.wish.com/c/5e9fa7de39682a0043ab7898
#
#                  product_id  listed_products  total_units_sold  \
# 0  5e9ae51d43d6a96e303acdb0                1               100
# 1  58940d436a0d3d5da4e95a38                6             21400
# 2  5df2576d68963c1660471f9a                6             21400
# 3  5d58daef3159a812b05933d2                6             21400
# 4  5e9fa7de39682a0043ab7898                6             21400
#
#    mean_units_sold_per_product  rating_employee  merchant_ratings_count  \
# 0                        100.0            4.129                   568.0
# 1                       3567.0            3.900                 17752.0
# 2                       3567.0            3.900                 17752.0
# 3                       3567.0            3.900                 17752.0
# 4                       3567.0            3.900                 17752.0
#
#    mean_product_prices  mean_retail_prices  mean_product_ratings_count  \
# 0                16.00               14.00                        54.0
# 1                 5.68               10.33                      1057.0
# 2                 5.68               10.33                      1057.0
# 3                 5.68               10.33                      1057.0
# 4                 5.68               10.33                      1057.0
#
#    discount_percentage seller_reputation
# 0               -200.0             Buena
# 1               1400.0           Regular
# 2                310.0           Regular
# 3                107.0           Regular
# 4                435.0           Regular

# %% [markdown]
# 9. Guarda los resultados en un DataFrame para usarlo en la próxima lección.

# %%
df_unido.to_csv("rating_insights1.csv")
