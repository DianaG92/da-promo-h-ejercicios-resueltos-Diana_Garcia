# %% [markdown]
# EJERCICIOS DE API´s

# %% [markdown]
# 1.  Utilizando la API de Balldontlie extrae la siguiente información.

# %% [markdown]
#    - El nombre, apellido y equipo de cada uno de los jugadores que tenemos en la NBA. Para eso tendrás que usar el [siguiente](http://api.balldontlie.io/v1/players) endpoint. Extrae información de los jugadores. Devuelve los resultados en un DataFrame. Te deberá quedar algo parecido a esto:
#
#         ![jugadores](https://github.com/Adalab/data_imagenes/blob/main/Modulo-2/api's_clase_invertida_jugadores.png?raw=true)

# %%
import pandas as pd
import requests

pd.set_option('display.max_columns', None)

# %%
api_key = "f876e6f8-1117-4a3b-af3f-03e4ac5532fb"

headers = {"Authorization": api_key}

# %%
def llamar_api(url, headers):
    
    llamada = requests.get(url, headers=headers)
    
    print(f"La llamada a la API nos ha dado una respuesta de tipo: {llamada.status_code}")
    
    if llamada.status_code != 200:
        print(f"El motivo por el que la llamada falló es {llamada.reason}")
    else:
        return llamada.json()  
    
url_jugadores = "http://api.balldontlie.io/v1/players"
   
resultados_jugadores = llamar_api(url_jugadores, headers)
# Out:
# La llamada a la API nos ha dado una respuesta de tipo: 200

# %%
if resultados_jugadores:

    informacion_jugadores = [{'nombres': jugadores['first_name'], 'apellidos': jugadores['last_name'], 'equipo': jugadores['team']['full_name']}
        
        for jugadores in resultados_jugadores['data']]
 
    df_equipos = pd.DataFrame(informacion_jugadores)
  
    print(df_equipos.head())  
    
else:
    print("No se pudo obtener la información de los jugadores.")
# Out:
#     nombres      apellidos                 equipo
# 0      Alex        Abrines  Oklahoma City Thunder
# 1    Jaylen          Adams          Atlanta Hawks
# 2    Steven          Adams        Houston Rockets
# 3       Bam        Adebayo             Miami Heat
# 4  DeVaughn  Akoon-Purcell         Denver Nuggets

# %% [markdown]
#  - Extrae información de todos los equipos, con la informacion que estos mismos traen,puedes encontrar la conferencia a la que pertenece, la ciudad, el nombre y su abreviacion. En este caso ustedes deben buscar por dentro de la pagina cual es la API que corresponderia a esta busqueda!!. Tambien dejar la informacion como un dataframe similar al ejemplo anterior.

# %%
def llamar_api(url, headers):
    
    llamada = requests.get(url, headers=headers)
   
    print(f"La llamada a la API nos ha dado una respuesta de tipo: {llamada.status_code}")
   
    if llamada.status_code != 200:
        print(f"El motivo por el que la llamada falló es {llamada.reason}")
    else:
        return llamada.json()  

url_equipos = "http://api.balldontlie.io/v1/teams"

resultados_equipos = llamar_api(url_equipos, headers)
# Out:
# La llamada a la API nos ha dado una respuesta de tipo: 200

# %%
resultados_equipos
# Out:
# {'data': [{'id': 1,
#    'conference': 'East',
#    'division': 'Southeast',
#    'city': 'Atlanta',
#    'name': 'Hawks',
#    'full_name': 'Atlanta Hawks',
#    'abbreviation': 'ATL'},
#   {'id': 2,
#    'conference': 'East',
#    'division': 'Atlantic',
#    'city': 'Boston',
#    'name': 'Celtics',
#    'full_name': 'Boston Celtics',
#    'abbreviation': 'BOS'},
#   {'id': 3,
#    'conference': 'East',
#    'division': 'Atlantic',
#    'city': 'Brooklyn',
#    'name': 'Nets',
#    'full_name': 'Brooklyn Nets',
#    'abbreviation': 'BKN'},
#   {'id': 4,
#    'conference': 'East',
#    'division': 'Southeast',
#    'city': 'Charlotte',
#    'name': 'Hornets',
#    'full_name': 'Charlotte Hornets',
#    'abbreviation': 'CHA'},
#   {'id': 5,
#    'conference': 'East',
#    'division': 'Central',
#    'city': 'Chicago',
#    'name': 'Bulls',
#    'full_name': 'Chicago Bulls',
#    'abbreviation': 'CHI'},
#   {'id': 6,
#    'conference': 'East',
#    'division': 'Central',
# ...

# %%
informacion_equipos = [{'nombre': equipos['full_name'],'ciudad': equipos['city'],'conferencia': equipos['conference'], 'abreviatura': equipos['abbreviation']}
        
        for equipos in resultados_equipos['data']]

df_equipos = pd.DataFrame(informacion_equipos)

print(df_equipos.head())
# Out:
#               nombre     ciudad conferencia abreviatura
# 0      Atlanta Hawks    Atlanta        East         ATL
# 1     Boston Celtics     Boston        East         BOS
# 2      Brooklyn Nets   Brooklyn        East         BKN
# 3  Charlotte Hornets  Charlotte        East         CHA
# 4      Chicago Bulls    Chicago        East         CHI
